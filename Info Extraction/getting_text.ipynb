# %%
def pdf2info(pdf,search_keyword):
    ''' Function to convert pdf to text and find matching sentences'''
    try:
        
        #Now give the pdf name
        pdf = pdf
        pdfFileObj = open(pdf, 'rb')
        pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
        #print(pdfReader.numPages) # will give total number of pages in pdf
        text_extract = []
        for i in range(pdfReader.numPages):
            pageObj = pdfReader.getPage(i)
            text=(pageObj.extractText())
            text=text.split(",")
            text_extract.append(text)
            
        x = sentence_finder(text_extract,search_keyword)
        return(x)
    except IOError:
        pass

# %%
def sentence_finder(text_extract, search_keyword):
    '''Function to extract the sentence with the matching search_keywords'''
    text = text_extract
    #print(text)
    #words = search_keywords
    for txt in text:
        for t in txt:
            txt1 = re.sub(r"\n+", " ", t)
            #print(txt1)
            sentences=sent_tokenize(txt1)
            #print(sentences)
            for sentence in sentences:
                words = word_tokenize(sentence.lower())
                for word in words:
                    if word == search_keyword.lower():
                        x = sentence
                        return x

# %%
import re
import PyPDF2
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

pdf = "C:/Users/nicyj/becode/KPMG/Data/NL_split_pdfs/NL_341-2021-015811.pdf"
search_keyword='werkgever'

extracted_sentences = pdf2info(pdf, search_keyword)
print(extracted_sentences)
# Out:
# Het recht opdebedrijfstoeslag blijft tenlaste van de werkgever ingeval van werkhervatting alswerkne- mer ofalszelfstandige.3 Letravailleur doit enoutre satisfaire àlacondition d'ancienneté quiestapplicable àlafinducontrat detravail auplus tard àlafindeson contrat detra- vail.

# %%
import pandas as pd
root_data_path = "C:/Users/nicyj/becode/KPMG"
data = pd.read_csv(root_data_path + '\Info Extraction\with erratum.csv')
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  deposit_number  jc_number  \
# 0             0           0          175235      100.0
# 1             1           1          170873      100.0
# 2             2           2          172225      100.0
# 3             3           3          172224      100.0
# 4             4           4          172223      100.0
#
#                                     Omschrijving  \
# 0  Aanvullend Paritair Comité voor de werklieden
# 1  Aanvullend Paritair Comité voor de werklieden
# 2  Aanvullend Paritair Comité voor de werklieden
# 3  Aanvullend Paritair Comité voor de werklieden
# 4  Aanvullend Paritair Comité voor de werklieden
#
#                                            Categorie  \
# 0  Paritaire organen bevoegd voor de werknemers d...
# 1  Paritaire organen bevoegd voor de werknemers d...
# 2  Paritaire organen bevoegd voor de werknemers d...
# 3  Paritaire organen bevoegd voor de werknemers d...
# 4  Paritaire organen bevoegd voor de werknemers d...
#
#                               jc_name_fr  \
# 0  auxiliary joint committee for workers
# 1  auxiliary joint committee for workers
# 2  auxiliary joint committee for workers
# 3  auxiliary joint committee for workers
# 4  auxiliary joint committee for workers
#
#                                       jc_name_nl  \
# 0  aanvullend paritair comite voor de werklieden
# 1  aanvullend paritair comite voor de werklieden
# 2  aanvullend paritair comite voor de werklieden
# 3  aanvullend paritair comite voor de werklieden
# 4  aanvullend paritair comite voor de werklieden
#
#                                         cla_title_en  \
# 0                                Minimum hourly wage
# 1    Sectoral agreement 2021-2022 - purchasing power
# 2  Exemption from the adapted availability obliga...
# 3                              Credit time 2021-2022
# 4  Increase in the internal overtime limit and th...
#
#                                         cla_title_nl  ... pub_roy_decree_date  \
# 0                                      Minimumurloon  ...                 NaN
# 1    Sectoral agreement 2021-2022 - purchasing power  ...                 NaN
# 2  Exemption from the obligation of adjusted avai...  ...                 NaN
# 3                              Time credit 2021-2022  ...                 NaN
# 4  Increasing the internal overtime limit and the...  ...                 NaN
#
#   corrected_date             filename doc_size          Themes  \
# 0            NaN  100-2022-011302.pdf   343 Kb  social benefit
# 1            NaN  100-2021-015127.pdf    196KB           wages
# 2            NaN  100-2021-015014.pdf    244KB  social benefit
# 3     2022-09-06  100-2021-015023.pdf    199KB  social benefit
# 4            NaN  100-2021-015028.pdf   141 KB    working time
#
#                                         Sub_Themes.1      NL_split_pdf_files  \
# 0                                                NaN  NL_100-2022-011302.pdf
# 1                                              wages  NL_100-2021-015127.pdf
# 2  unemployment scheme with company supplement (rcc)  NL_100-2021-015014.pdf
# 3  time credit/career reduction, end of career em...  NL_100-2021-015023.pdf
# 4                           working time flexibility  NL_100-2021-015028.pdf
#
#                                              Summary  \
# 0                                               None
# 1  Hoofdstuk IV-Regeling voor ondernemingen waar ...
# 2  Deze collectieve arbeidsovereenkomst moet gele...
# 3  FEDERALE OVERHEIDSDIENST Werkgelegenheid Arbei...
# 4  Pour lesentreprises quioccupent moins de50ouvr...
#
#                                              ERRATUM            prev_cla_no
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3  ['FEDERALE OVERHEIDSDIENST\nWerkgelegenheid', ...  nr.172224/co/100\nvan
# 4                                                NaN                    NaN
#
# [5 rows x 32 columns]

# %%
## MAIN ##

import PyPDF2
import pandas as pd
import re
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

root_data_path = "C:/Users/nicyj/becode/KPMG"
folder = "/Data/NL_split_pdfs/"
#pdf_filename = "100-2021-015127.pdf"

data = pd.read_csv(root_data_path + '\Info Extraction\with erratum.csv')
pdf_list = data['NL_split_pdf_files']

toepassing = []
loon = []
duur = []
premie = []

for i in range(len(pdf_list)):
    pdf_filename = pdf_list[i]
    #print(pdf_filename)
    pdf = root_data_path + folder + pdf_filename
    
    search_keywords=['toepassing']
    for search_keyword in search_keywords:
        extracted_sentences = pdf2info(pdf, search_keyword)
        toepassing.append(extracted_sentences)
        
    search_keywords=['loon']
    for search_keyword in search_keywords:
        extracted_sentences = pdf2info(pdf, search_keyword)
        loon.append(extracted_sentences)
        
    search_keywords=['premie']
    for search_keyword in search_keywords:
        extracted_sentences = pdf2info(pdf, search_keyword)
        premie.append(extracted_sentences)
        
    search_keywords=['duur']
    for search_keyword in search_keywords:
        extracted_sentences = pdf2info(pdf, search_keyword)
        duur.append(extracted_sentences)
       
data['toepassing'] = toepassing
data['loon'] = loon
data['duur'] = duur
data['premie'] = premie
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  deposit_number  jc_number  \
# 0             0           0          175235      100.0
# 1             1           1          170873      100.0
# 2             2           2          172225      100.0
# 3             3           3          172224      100.0
# 4             4           4          172223      100.0
#
#                                     Omschrijving  \
# 0  Aanvullend Paritair Comité voor de werklieden
# 1  Aanvullend Paritair Comité voor de werklieden
# 2  Aanvullend Paritair Comité voor de werklieden
# 3  Aanvullend Paritair Comité voor de werklieden
# 4  Aanvullend Paritair Comité voor de werklieden
#
#                                            Categorie  \
# 0  Paritaire organen bevoegd voor de werknemers d...
# 1  Paritaire organen bevoegd voor de werknemers d...
# 2  Paritaire organen bevoegd voor de werknemers d...
# 3  Paritaire organen bevoegd voor de werknemers d...
# 4  Paritaire organen bevoegd voor de werknemers d...
#
#                               jc_name_fr  \
# 0  auxiliary joint committee for workers
# 1  auxiliary joint committee for workers
# 2  auxiliary joint committee for workers
# 3  auxiliary joint committee for workers
# 4  auxiliary joint committee for workers
#
#                                       jc_name_nl  \
# 0  aanvullend paritair comite voor de werklieden
# 1  aanvullend paritair comite voor de werklieden
# 2  aanvullend paritair comite voor de werklieden
# 3  aanvullend paritair comite voor de werklieden
# 4  aanvullend paritair comite voor de werklieden
#
#                                         cla_title_en  \
# 0                                Minimum hourly wage
# 1    Sectoral agreement 2021-2022 - purchasing power
# 2  Exemption from the adapted availability obliga...
# 3                              Credit time 2021-2022
# 4  Increase in the internal overtime limit and th...
#
#                                         cla_title_nl  ...          Themes  \
# 0                                      Minimumurloon  ...  social benefit
# 1    Sectoral agreement 2021-2022 - purchasing power  ...           wages
# 2  Exemption from the obligation of adjusted avai...  ...  social benefit
# 3                              Time credit 2021-2022  ...  social benefit
# 4  Increasing the internal overtime limit and the...  ...    working time
#
#                                         Sub_Themes.1      NL_split_pdf_files  \
# 0                                                NaN  NL_100-2022-011302.pdf
# 1                                              wages  NL_100-2021-015127.pdf
# 2  unemployment scheme with company supplement (rcc)  NL_100-2021-015014.pdf
# 3  time credit/career reduction, end of career em...  NL_100-2021-015023.pdf
# 4                           working time flexibility  NL_100-2021-015028.pdf
#
#                                              Summary  \
# 0                                               None
# 1  Hoofdstuk IV-Regeling voor ondernemingen waar ...
# 2  Deze collectieve arbeidsovereenkomst moet gele...
# 3  FEDERALE OVERHEIDSDIENST Werkgelegenheid Arbei...
# 4  Pour lesentreprises quioccupent moins de50ouvr...
#
#                                              ERRATUM            prev_cla_no  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3  ['FEDERALE OVERHEIDSDIENST\nWerkgelegenheid', ...  nr.172224/co/100\nvan
# 4                                                NaN                    NaN
#
#                                           toepassing  \
# 0                                               None
# 1  : 07/03/2022 W:170873/CO/1 00 COLLECTIEVE ARBE...
# 2   alsook decollectieve ar- beidsovereenkomsten ...
# 3   onentend lesouvriers masculins etféminins.Hoo...
# 4  Aanvullend Paritair Comité voor dewerklieden C...
#
#                                                 loon  \
# 0                                               None
# 1   coronapremies en automatische verhogingen van...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                 duur  premie
# 0                                               None    None
# 1  Hoofdstuk VI-Duur Artikel6 Deze collectieve ar...    None
# 2                                               None    None
# 3  Chapitre IV:Durée dela Hoofdstuk IV:Duur van d...    None
# 4  3.Deze collectieve arbeidsovereenkomst isge- s...    None
#
# [5 rows x 36 columns]

# %%
werkgever = []
for i in range(len(pdf_list)):
    pdf_filename = pdf_list[i]
    #print(pdf_filename)
    pdf = root_data_path + folder + pdf_filename
    
    search_keywords=['werkgever']
    for search_keyword in search_keywords:
        extracted_sentences = pdf2info(pdf, search_keyword)
        werkgever.append(extracted_sentences)

data['Werkgever'] = werkgever
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  deposit_number  jc_number  \
# 0             0           0          175235      100.0
# 1             1           1          170873      100.0
# 2             2           2          172225      100.0
# 3             3           3          172224      100.0
# 4             4           4          172223      100.0
#
#                                     Omschrijving  \
# 0  Aanvullend Paritair Comité voor de werklieden
# 1  Aanvullend Paritair Comité voor de werklieden
# 2  Aanvullend Paritair Comité voor de werklieden
# 3  Aanvullend Paritair Comité voor de werklieden
# 4  Aanvullend Paritair Comité voor de werklieden
#
#                                            Categorie  \
# 0  Paritaire organen bevoegd voor de werknemers d...
# 1  Paritaire organen bevoegd voor de werknemers d...
# 2  Paritaire organen bevoegd voor de werknemers d...
# 3  Paritaire organen bevoegd voor de werknemers d...
# 4  Paritaire organen bevoegd voor de werknemers d...
#
#                               jc_name_fr  \
# 0  auxiliary joint committee for workers
# 1  auxiliary joint committee for workers
# 2  auxiliary joint committee for workers
# 3  auxiliary joint committee for workers
# 4  auxiliary joint committee for workers
#
#                                       jc_name_nl  \
# 0  aanvullend paritair comite voor de werklieden
# 1  aanvullend paritair comite voor de werklieden
# 2  aanvullend paritair comite voor de werklieden
# 3  aanvullend paritair comite voor de werklieden
# 4  aanvullend paritair comite voor de werklieden
#
#                                         cla_title_en  \
# 0                                Minimum hourly wage
# 1    Sectoral agreement 2021-2022 - purchasing power
# 2  Exemption from the adapted availability obliga...
# 3                              Credit time 2021-2022
# 4  Increase in the internal overtime limit and th...
#
#                                         cla_title_nl  ...  \
# 0                                      Minimumurloon  ...
# 1    Sectoral agreement 2021-2022 - purchasing power  ...
# 2  Exemption from the obligation of adjusted avai...  ...
# 3                              Time credit 2021-2022  ...
# 4  Increasing the internal overtime limit and the...  ...
#
#                                         Sub_Themes.1      NL_split_pdf_files  \
# 0                                                NaN  NL_100-2022-011302.pdf
# 1                                              wages  NL_100-2021-015127.pdf
# 2  unemployment scheme with company supplement (rcc)  NL_100-2021-015014.pdf
# 3  time credit/career reduction, end of career em...  NL_100-2021-015023.pdf
# 4                           working time flexibility  NL_100-2021-015028.pdf
#
#                                              Summary  \
# 0                                               None
# 1  Hoofdstuk IV-Regeling voor ondernemingen waar ...
# 2  Deze collectieve arbeidsovereenkomst moet gele...
# 3  FEDERALE OVERHEIDSDIENST Werkgelegenheid Arbei...
# 4  Pour lesentreprises quioccupent moins de50ouvr...
#
#                                              ERRATUM            prev_cla_no  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3  ['FEDERALE OVERHEIDSDIENST\nWerkgelegenheid', ...  nr.172224/co/100\nvan
# 4                                                NaN                    NaN
#
#                                           toepassing  \
# 0                                               None
# 1  : 07/03/2022 W:170873/CO/1 00 COLLECTIEVE ARBE...
# 2   alsook decollectieve ar- beidsovereenkomsten ...
# 3   onentend lesouvriers masculins etféminins.Hoo...
# 4  Aanvullend Paritair Comité voor dewerklieden C...
#
#                                                 loon  \
# 0                                               None
# 1   coronapremies en automatische verhogingen van...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                 duur premie  Werkgever
# 0                                               None   None       None
# 1  Hoofdstuk VI-Duur Artikel6 Deze collectieve ar...   None       None
# 2                                               None   None       None
# 3  Chapitre IV:Durée dela Hoofdstuk IV:Duur van d...   None       None
# 4  3.Deze collectieve arbeidsovereenkomst isge- s...   None       None
#
# [5 rows x 37 columns]

# %%
werkloosheid = []
for i in range(len(pdf_list)):
    pdf_filename = pdf_list[i]
    #print(pdf_filename)
    pdf = root_data_path + folder + pdf_filename
    
    search_keywords=['werkloosheid']
    for search_keyword in search_keywords:
        extracted_sentences = pdf2info(pdf, search_keyword)
        werkloosheid.append(extracted_sentences)

data['werkloosheid'] = werkloosheid
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  deposit_number  jc_number  \
# 0             0           0          175235      100.0
# 1             1           1          170873      100.0
# 2             2           2          172225      100.0
# 3             3           3          172224      100.0
# 4             4           4          172223      100.0
#
#                                     Omschrijving  \
# 0  Aanvullend Paritair Comité voor de werklieden
# 1  Aanvullend Paritair Comité voor de werklieden
# 2  Aanvullend Paritair Comité voor de werklieden
# 3  Aanvullend Paritair Comité voor de werklieden
# 4  Aanvullend Paritair Comité voor de werklieden
#
#                                            Categorie  \
# 0  Paritaire organen bevoegd voor de werknemers d...
# 1  Paritaire organen bevoegd voor de werknemers d...
# 2  Paritaire organen bevoegd voor de werknemers d...
# 3  Paritaire organen bevoegd voor de werknemers d...
# 4  Paritaire organen bevoegd voor de werknemers d...
#
#                               jc_name_fr  \
# 0  auxiliary joint committee for workers
# 1  auxiliary joint committee for workers
# 2  auxiliary joint committee for workers
# 3  auxiliary joint committee for workers
# 4  auxiliary joint committee for workers
#
#                                       jc_name_nl  \
# 0  aanvullend paritair comite voor de werklieden
# 1  aanvullend paritair comite voor de werklieden
# 2  aanvullend paritair comite voor de werklieden
# 3  aanvullend paritair comite voor de werklieden
# 4  aanvullend paritair comite voor de werklieden
#
#                                         cla_title_en  \
# 0                                Minimum hourly wage
# 1    Sectoral agreement 2021-2022 - purchasing power
# 2  Exemption from the adapted availability obliga...
# 3                              Credit time 2021-2022
# 4  Increase in the internal overtime limit and th...
#
#                                         cla_title_nl  ...  \
# 0                                      Minimumurloon  ...
# 1    Sectoral agreement 2021-2022 - purchasing power  ...
# 2  Exemption from the obligation of adjusted avai...  ...
# 3                              Time credit 2021-2022  ...
# 4  Increasing the internal overtime limit and the...  ...
#
#        NL_split_pdf_files                                            Summary  \
# 0  NL_100-2022-011302.pdf                                               None
# 1  NL_100-2021-015127.pdf  Hoofdstuk IV-Regeling voor ondernemingen waar ...
# 2  NL_100-2021-015014.pdf  Deze collectieve arbeidsovereenkomst moet gele...
# 3  NL_100-2021-015023.pdf  FEDERALE OVERHEIDSDIENST Werkgelegenheid Arbei...
# 4  NL_100-2021-015028.pdf  Pour lesentreprises quioccupent moins de50ouvr...
#
#                                              ERRATUM            prev_cla_no  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3  ['FEDERALE OVERHEIDSDIENST\nWerkgelegenheid', ...  nr.172224/co/100\nvan
# 4                                                NaN                    NaN
#
#                                           toepassing  \
# 0                                               None
# 1  : 07/03/2022 W:170873/CO/1 00 COLLECTIEVE ARBE...
# 2   alsook decollectieve ar- beidsovereenkomsten ...
# 3   onentend lesouvriers masculins etféminins.Hoo...
# 4  Aanvullend Paritair Comité voor dewerklieden C...
#
#                                                 loon  \
# 0                                               None
# 1   coronapremies en automatische verhogingen van...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                 duur premie Werkgever  \
# 0                                               None   None      None
# 1  Hoofdstuk VI-Duur Artikel6 Deze collectieve ar...   None      None
# 2                                               None   None      None
# 3  Chapitre IV:Durée dela Hoofdstuk IV:Duur van d...   None      None
# 4  3.Deze collectieve arbeidsovereenkomst isge- s...   None      None
#
#                                         werkloosheid
# 0                                               None
# 1                                               None
# 2   van devoorwaar- den voor detoekenning van dev...
# 3                                               None
# 4                                               None
#
# [5 rows x 38 columns]

# %%
bonus = []
for i in range(len(pdf_list)):
    pdf_filename = pdf_list[i]
    #print(pdf_filename)
    pdf = root_data_path + folder + pdf_filename
    
    search_keywords=['bonus']
    for search_keyword in search_keywords:
        extracted_sentences = pdf2info(pdf, search_keyword)
        bonus.append(extracted_sentences)

data['bonus'] = bonus
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  deposit_number  jc_number  \
# 0             0           0          175235      100.0
# 1             1           1          170873      100.0
# 2             2           2          172225      100.0
# 3             3           3          172224      100.0
# 4             4           4          172223      100.0
#
#                                     Omschrijving  \
# 0  Aanvullend Paritair Comité voor de werklieden
# 1  Aanvullend Paritair Comité voor de werklieden
# 2  Aanvullend Paritair Comité voor de werklieden
# 3  Aanvullend Paritair Comité voor de werklieden
# 4  Aanvullend Paritair Comité voor de werklieden
#
#                                            Categorie  \
# 0  Paritaire organen bevoegd voor de werknemers d...
# 1  Paritaire organen bevoegd voor de werknemers d...
# 2  Paritaire organen bevoegd voor de werknemers d...
# 3  Paritaire organen bevoegd voor de werknemers d...
# 4  Paritaire organen bevoegd voor de werknemers d...
#
#                               jc_name_fr  \
# 0  auxiliary joint committee for workers
# 1  auxiliary joint committee for workers
# 2  auxiliary joint committee for workers
# 3  auxiliary joint committee for workers
# 4  auxiliary joint committee for workers
#
#                                       jc_name_nl  \
# 0  aanvullend paritair comite voor de werklieden
# 1  aanvullend paritair comite voor de werklieden
# 2  aanvullend paritair comite voor de werklieden
# 3  aanvullend paritair comite voor de werklieden
# 4  aanvullend paritair comite voor de werklieden
#
#                                         cla_title_en  \
# 0                                Minimum hourly wage
# 1    Sectoral agreement 2021-2022 - purchasing power
# 2  Exemption from the adapted availability obliga...
# 3                              Credit time 2021-2022
# 4  Increase in the internal overtime limit and th...
#
#                                         cla_title_nl  ...  \
# 0                                      Minimumurloon  ...
# 1    Sectoral agreement 2021-2022 - purchasing power  ...
# 2  Exemption from the obligation of adjusted avai...  ...
# 3                              Time credit 2021-2022  ...
# 4  Increasing the internal overtime limit and the...  ...
#
#                                              Summary  \
# 0                                               None
# 1  Hoofdstuk IV-Regeling voor ondernemingen waar ...
# 2  Deze collectieve arbeidsovereenkomst moet gele...
# 3  FEDERALE OVERHEIDSDIENST Werkgelegenheid Arbei...
# 4  Pour lesentreprises quioccupent moins de50ouvr...
#
#                                              ERRATUM            prev_cla_no  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3  ['FEDERALE OVERHEIDSDIENST\nWerkgelegenheid', ...  nr.172224/co/100\nvan
# 4                                                NaN                    NaN
#
#                                           toepassing  \
# 0                                               None
# 1  : 07/03/2022 W:170873/CO/1 00 COLLECTIEVE ARBE...
# 2   alsook decollectieve ar- beidsovereenkomsten ...
# 3   onentend lesouvriers masculins etféminins.Hoo...
# 4  Aanvullend Paritair Comité voor dewerklieden C...
#
#                                                 loon  \
# 0                                               None
# 1   coronapremies en automatische verhogingen van...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                 duur premie Werkgever  \
# 0                                               None   None      None
# 1  Hoofdstuk VI-Duur Artikel6 Deze collectieve ar...   None      None
# 2                                               None   None      None
# 3  Chapitre IV:Durée dela Hoofdstuk IV:Duur van d...   None      None
# 4  3.Deze collectieve arbeidsovereenkomst isge- s...   None      None
#
#                                         werkloosheid  bonus
# 0                                               None   None
# 1                                               None   None
# 2   van devoorwaar- den voor detoekenning van dev...   None
# 3                                               None   None
# 4                                               None   None
#
# [5 rows x 39 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1                0
# Unnamed: 0                  0
# deposit_number              0
# jc_number                   0
# Omschrijving              302
# Categorie                 302
# jc_name_fr                  0
# jc_name_nl                  0
# cla_title_en                0
# cla_title_nl                0
# retrieve_date               0
# label                       0
# themes_en                 413
# themes_nl                 413
# signature_date              0
# validity_date            1882
# deposit_date                0
# record_date                 0
# deposit_reg_date            0
# enforced                    0
# royal_decree_date        1123
# notice_depositMB_date      62
# pub_roy_decree_date      1856
# corrected_date           4777
# filename                    0
# doc_size                    0
# Themes                      0
# Sub_Themes.1              413
# NL_split_pdf_files          0
# Summary                     0
# ERRATUM                  5432
# prev_cla_no              5432
# toepassing               3759
# loon                     5261
# duur                     4420
# premie                   5360
# Werkgever                4842
# werkloosheid             4806
# bonus                    5669
# dtype: int64

# %%
data.to_csv('final.csv', index = True)
